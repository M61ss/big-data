# %% [markdown]
# # Traccia:

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Caricare il dataset "winemag-data_first150k.csv" all'interno di un DataFrame pandas

# %%
df = pd.read_csv("../data/winemag-data_first150k.csv", sep=',')
df.head(3)
# Out:
#    id country                                        description  \
# 0   0      US  This tremendous 100% varietal wine hails from ...
# 1   1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2   2      US  Mac Watson honors the memory of a wine once ma...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
#
#          region_1 region_2             variety                   winery
# 0     Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1            Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2  Knights Valley   Sonoma     Sauvignon Blanc                 Macauley

# %%
df.shape
# Out:
# (150930, 11)

# %%
len(df)
# Out:
# 150930

# %%
df.columns
# Out:
# Index(['id', 'country', 'description', 'designation', 'points', 'price',
#        'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# 2. Visualizzare tramite un bar plot le 10 province dalle quali si producono più vini (ovvero con un conteggio di vini maggiore). Cosa si evince dal grafico?

# %%
df['province'].value_counts().head(10).plot.bar()
# Out:
# <Axes: xlabel='province'>

# %% [markdown]
# 3. Visualizzare tramite un bar plot le 10 province dalle quali si producono più vini. Visualizzare questa volta dati percentuali. Cosa si evince dal grafico?

# %%
s = df['province'].value_counts().head(10)
s = (s / len(df)) * 100
s.plot.bar()
# Out:
# <Axes: xlabel='province'>

# %% [markdown]
# 4. Visualizzare tramite un bar plot il conteggio dei voti (colonna points) assegnati alle varie recensioni. Qual è il voto che è stato assegnato al maggior numero di recensioni?

# %%
df['points'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='points'>

# %% [markdown]
# 5. Modificare il grafico precedente in modo da visualizzare i voti in senso crescente.

# %%
df['points'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='points'>

# %% [markdown]
# 6. Visualizzare la stessa informazione del grafico del punto 5 con un grafico a linea

# %%
df['points'].value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='points'>

# %% [markdown]
# 7. Visualizzare con un istogramma la frequenza dei voti assegnati nelle varie recensioni.  Visualizzare il grafico anche con seaborn.

# %%
df['points'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 8. Visualizzare con un istogramma la frequenza del prezzo dei vini.

# %%
df.columns
# Out:
# Index(['id', 'country', 'description', 'designation', 'points', 'price',
#        'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
df['price'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['price'] > 900]
# Out:
#           id   country                                        description  \
# 10651  10651   Austria  Wet earth, rain-wet stones, damp moss, wild sa...
# 10886  10886  Portugal  This was a great vintage Port year, and this w...
# 13318  13318        US  The nose on this single-vineyard wine from a s...
# 26296  26296    France  A wine that has created its own universe. It h...
# 34920  34920    France  A big, powerful wine that sums up the richness...
# 34922  34922    France  A massive wine for Margaux, packed with tannin...
# 34927  34927    France  Such a generous and ripe wine, with a dark cor...
# 34939  34939    France  The purest Cabernet Sauvignon fruit, with dark...
# 34942  34942    France  Solid, very structured, packed with dense and ...
# 35531  35531    France  This is the first vintage of a wine that used ...
# 51886  51886    France  A wine that has created its own universe. It h...
# 83536  83536    France  A wine that has created its own universe. It h...
#
#                    designation  points   price    province        region_1  \
# 10651  Ried Loibenberg Smaragd      94  1100.0      Wachau             NaN
# 10886           Colheita White      94   980.0        Port             NaN
# 13318      Roger Rose Vineyard      91  2013.0  California     Arroyo Seco
# 26296           Clos du Mesnil     100  1400.0   Champagne       Champagne
# 34920                      NaN      99  2300.0    Bordeaux        Pauillac
# 34922                      NaN      98  1900.0    Bordeaux         Margaux
# 34927                      NaN      97  1100.0    Bordeaux  Pessac-Léognan
# 34939                      NaN      96  1300.0    Bordeaux        Pauillac
# 34942                      NaN      96  1200.0    Bordeaux  Pessac-Léognan
# 35531                      NaN      94  1000.0    Bordeaux  Pessac-Léognan
# 51886           Clos du Mesnil     100  1400.0   Champagne       Champagne
# 83536           Clos du Mesnil     100  1400.0   Champagne       Champagne
#
#             region_2                     variety  \
# 10651            NaN            Grüner Veltliner
# 10886            NaN                        Port
# 13318  Central Coast                  Chardonnay
# 26296            NaN                  Chardonnay
# 34920            NaN    Bordeaux-style Red Blend
# 34922            NaN    Bordeaux-style Red Blend
# 34927            NaN    Bordeaux-style Red Blend
# 34939            NaN    Bordeaux-style Red Blend
# 34942            NaN    Bordeaux-style Red Blend
# 35531            NaN  Bordeaux-style White Blend
# 51886            NaN                  Chardonnay
# 83536            NaN                  Chardonnay
#
#                               winery
# 10651                 Emmerich Knoll
# 10886                          Kopke
# 13318                          Blair
# 26296                           Krug
# 34920                 Château Latour
# 34922                Château Margaux
# 34927  Château La Mission Haut-Brion
# 34939      Château Mouton Rothschild
# 34942             Château Haut-Brion
# 35531  Château La Mission Haut-Brion
# 51886                           Krug
# 83536                           Krug

# %% [markdown]
# 9. Visualizzare con un istogramma la frequenza del prezzo dei vini che costano meno di 200 dollari.

# %%
df[df['price'] < 200]['price'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 10. Visualizzare con uno scatter plot la relazione che sussiste tra voti assegnati nelle recensioni e prezzo del vino. Selezionare un sample di 100 elementi. Cosa è possibile notare? Visualizzare il grafico anche con seaborn.

# %%
df.columns
# Out:
# Index(['id', 'country', 'description', 'designation', 'points', 'price',
#        'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
dfnew = df.sample(10000)
dfnew.plot.scatter(x='price', y='points')
# Out:
# <Axes: xlabel='price', ylabel='points'>

# %%
dfnew['price'].min()
# Out:
# np.float64(5.0)

# %%
dfnew['price'].max()
# Out:
# np.float64(1000.0)

# %% [markdown]
# 11. Selezionare le sole recensioni che si riferiscono alle seguenti varietà di vini: "Bordeaux-style Red Blend", "Cabernet Sauvignon", "Chardonnay", "Pinot Noir", "Red Blend". Raggruppare i vini per voto e varietà e conteggiarli (usare un group by). Visualizzare questa informazione con un bar plot stacked.

# %%
df.columns
# Out:
# Index(['id', 'country', 'description', 'designation', 'points', 'price',
#        'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
vini = ["Bordeaux-style Red Blend", "Cabernet Sauvignon", "Chardonnay", "Pinot Noir", "Red Blend"]

dfnew = df[df['variety'].isin(vini)].groupby(['points', 'variety']).size().unstack()
dfnew.plot.box()
# Out:
# <Axes: >

# %%
dfnew
# Out:
# variety  Bordeaux-style Red Blend  Cabernet Sauvignon  Chardonnay  Pinot Noir  \
# points
# 80                            5.0                89.0        70.0        36.0
# 81                           23.0               160.0       154.0        86.0
# 82                           83.0               436.0       523.0       296.0
# 83                          122.0               571.0       686.0       350.0
# 84                          334.0               925.0      1170.0       757.0
# 85                          379.0              1058.0      1299.0       903.0
# 86                          467.0              1205.0      1525.0      1260.0
# 87                          679.0              1589.0      1887.0      1784.0
# 88                          741.0              1160.0      1513.0      1586.0
# 89                          724.0               920.0      1039.0      1223.0
# 90                          901.0              1341.0      1435.0      1646.0
# 91                          821.0               825.0       938.0      1124.0
# 92                          733.0              1018.0       953.0      1173.0
# 93                          556.0               653.0       671.0       992.0
# 94                          338.0               440.0       325.0       621.0
# 95                          220.0               233.0       188.0       269.0
# 96                          124.0               102.0        73.0       105.0
# 97                           67.0                56.0        23.0        56.0
# 98                           22.0                12.0         7.0        20.0
# 99                            8.0                 4.0         NaN         2.0
# 100                           NaN                 3.0         3.0         2.0
#
# variety  Red Blend
# points
# 80            75.0
# 81           108.0
# 82           233.0
# 83           366.0
# 84           623.0
# 85           608.0
# 86           919.0
# 87          1375.0
# 88          1366.0
# 89          1013.0
# 90          1132.0
# 91           881.0
# 92           620.0
# 93           395.0
# 94           190.0
# 95            88.0
# 96            30.0
# 97            27.0
# 98             6.0
# 99             5.0
# 100            2.0

# %%
dfnew.fillna(0, inplace=True)

# %% [markdown]
# 12. Visualizzare l'informazione precedente con un plot area ed un line chart.

# %%
dfnew.plot()
# Out:
# <Axes: xlabel='points'>

# %%
dfnew.plot.area()
# Out:
# <Axes: xlabel='points'>

# %% [markdown]
# 13. Visualizzare con un box plot (con seaborn) la distribuzione dei voti per le 5 varietà di vini "Bordeaux-style Red Blend", "Cabernet Sauvignon", "Chardonnay", "Pinot Noir", "Red Blend".

# %%
vini
# Out:
# ['Bordeaux-style Red Blend',
#  'Cabernet Sauvignon',
#  'Chardonnay',
#  'Pinot Noir',
#  'Red Blend']

# %%
dfnew = df[df['variety'].isin(vini)]
dfnew
# Out:
#             id country                                        description  \
# 0            0      US  This tremendous 100% varietal wine hails from ...
# 3            3      US  This spent 20 months in 30% new French oak, an...
# 8            8      US  This re-named vineyard was formerly bottled as...
# 9            9      US  The producer sources from two blocks of the vi...
# 11          11      US  From 18-year-old vines, this supple well-balan...
# ...        ...     ...                                                ...
# 150908  150908  France  Another premier cru from Michel Gros, this one...
# 150909  150909  France  This is a lovely, fragrant Burgundy, with a sm...
# 150910  150910  France  Scents of graham cracker and malted milk choco...
# 150911  150911  France  This needs a good bit of breathing time, then ...
# 150912  150912  France  The nose is dominated by the attractive scents...
#
#                             designation  points  price    province  \
# 0                     Martha's Vineyard      96  235.0  California
# 3                               Reserve      96   65.0      Oregon
# 8                                Silice      95   65.0      Oregon
# 9                  Gap's Crown Vineyard      95   60.0  California
# 11      Estate Vineyard Wadensvil Block      95   48.0      Oregon
# ...                                 ...     ...    ...         ...
# 150908                      Aux Brulees      90   65.0    Burgundy
# 150909             Clos dea Argillieres      89   52.0    Burgundy
# 150910                              NaN      89   38.0    Burgundy
# 150911                     Les Chaliots      87   37.0    Burgundy
# 150912                      Les Charmes      87   65.0    Burgundy
#
#                   region_1           region_2             variety  \
# 0              Napa Valley               Napa  Cabernet Sauvignon
# 3        Willamette Valley  Willamette Valley          Pinot Noir
# 8       Chehalem Mountains  Willamette Valley          Pinot Noir
# 9             Sonoma Coast             Sonoma          Pinot Noir
# 11            Ribbon Ridge  Willamette Valley          Pinot Noir
# ...                    ...                ...                 ...
# 150908       Vosne-Romanée                NaN          Pinot Noir
# 150909   Nuits-St.-Georges                NaN          Pinot Noir
# 150910   Chambolle-Musigny                NaN          Pinot Noir
# 150911   Nuits-St.-Georges                NaN          Pinot Noir
# 150912   Chambolle-Musigny                NaN          Pinot Noir
#
#                         winery
# 0                        Heitz
# 3                        Ponzi
# 8                    Bergström
# 9                    Blue Farm
# 11      Patricia Green Cellars
# ...                        ...
# 150908             Michel Gros
# 150909             Daniel Rion
# 150910             Michel Gros
# 150911             Michel Gros
# 150912             Daniel Rion
#
# [58982 rows x 11 columns]

# %%
dfnew[['variety', 'points']].hist()
# Out:
# array([[<Axes: title={'center': 'points'}>]], dtype=object)

# %% [markdown]
# 14. Visualizzare con seaborn un istogramma relativo alla frequenza di voti per ognuna delle 5 varietà di vini precedenti. Utilizzare FacetGrid.

# %%
import seaborn as sns

dfnew = df[df['variety'].isin(vini)]
sns.FacetGrid(dfnew[['variety', 'points']]).map(plt.hist, 'variety', 'points')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 4
#       1 import seaborn as sns
#       3 dfnew = df[df['variety'].isin(vini)]
# ----> 4 sns.FacetGrid(dfnew[['variety', 'points']]).map(plt.hist, 'variety', 'points', bins=10)
#       5 plt.show()
#
# File ~/miniconda3/envs/big-data/lib/python3.11/site-packages/seaborn/axisgrid.py:758, in FacetGrid.map(self, func, *args, **kwargs)
#     755         plot_args = [v.values for v in plot_args]
#     757     # Draw the plot
# --> 758     self._facet_plot(func, ax, plot_args, kwargs)
#     760 # Finalize the annotations and layout
#     761 self._finalize_grid(args[:2])
#
# File ~/miniconda3/envs/big-data/lib/python3.11/site-packages/seaborn/axisgrid.py:854, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     852     plot_args = []
#     853     plot_kwargs["ax"] = ax
# --> 854 func(*plot_args, **plot_kwargs)
#     856 # Sort out the supporting information
#     857 self._update_legend_data(ax)
#
# File ~/miniconda3/envs/big-data/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: hist() got multiple values for argument 'bins'

# %% [markdown]
# 15. Visualizzare con pairplot seaborn una comparison tra il prezzo dei vini e i voti associati. Selezionare un sample di 100 elementi e rimuovere prima i valori nulli.

# %%
dfnew = df.sample(100).dropna()
sns.pairplot(dfnew[['points', 'price']])

# %% [markdown]
# 16. Visualizzare in un heatmap seaborn la correlazione tra il prezzo dei vini e i voti associati.

# %%
sns.heatmap(df[['points', 'price']].corr())
# Out:
# <Axes: >
